# %%
import pandas as pd

df = pd.read_csv('Numeros1.csv', encoding='ISO-8859-1')
df
# Out:
#      consumo   valor
# 0         33    8.25
# 1        123   30.75
# 2       2540  635.00
# 3       1510  377.50
# 4       2930  732.50
# ..       ...     ...
# 495     3000  750.00
# 496      867  216.75
# 497     1772  443.00
# 498     2407  601.75
# 499     2048  512.00
#
# [500 rows x 2 columns]

# %%
# Gráfico de dispersão

df.plot(kind="scatter", x="consumo", y="valor" );

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Criando um modelo de Machine Learning

modelo = linear_model.LinearRegression()

# %%
x = df[['consumo']]
y = df[['valor']]

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y)

# %%
# Treinando o modelo de Machine Learning

modelo.fit(x_treino, y_treino)
# Out:
# LinearRegression()

# %%
previsoes = modelo.predict(x_teste)

# %%
# Testando o modelo e a porcentagem de acerto nas previsões

acuracidade = round(r2_score(y_teste, previsoes) * 100, 2)
print(f'A acuracidade do modelo é de {acuracidade}%')
# Out:
# A acuracidade do modelo é de 100.0%

# %%
import pickle

with open("modelo_treinado.pkl", "wb") as file:
    pickle.dump(modelo, file)
